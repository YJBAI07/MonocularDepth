# %%
import os, gc, cv2, torch, shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from transformers import AutoImageProcessor, ZoeDepthForDepthEstimation

# ================== 模型加载 ==================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_name = "Intel/zoedepth-nyu-kitti"
processor = AutoImageProcessor.from_pretrained(model_name)
model = ZoeDepthForDepthEstimation.from_pretrained(model_name).to(device)

# ================== 可视化（4 连图） ==================
def save_comparison_figure(img_name, rgb, gt, pred_metric, pred_aligned, mask, vis_dir):
    os.makedirs(vis_dir, exist_ok=True)
    save_path = os.path.join(vis_dir, img_name.replace(".png", "_compare.png"))

    valid_m = mask & (gt > 0) & np.isfinite(gt) & np.isfinite(pred_metric)
    valid_a = mask & (gt > 0) & np.isfinite(gt) & np.isfinite(pred_aligned)
    pool = []
    if np.any(valid_m):
        pool += [gt[valid_m], pred_metric[valid_m]]
    if np.any(valid_a):
        pool += [gt[valid_a], pred_aligned[valid_a]]
    if len(pool) == 0:
        pool = [gt[mask & (gt > 0)]] if np.any(mask & (gt > 0)) else [gt.flatten()]
    pool = np.concatenate(pool)
    vmin, vmax = np.percentile(pool, 2), np.percentile(pool, 98)

    plt.figure(figsize=(20, 5))
    plt.subplot(1, 4, 1); plt.imshow(rgb); plt.title("RGB"); plt.axis("off")
    plt.subplot(1, 4, 2); plt.imshow(np.where(mask, gt, np.nan), cmap="viridis", vmin=vmin, vmax=vmax)
    plt.title("GT Depth"); plt.colorbar(fraction=0.046, pad=0.04); plt.axis("off")
    plt.subplot(1, 4, 3); plt.imshow(np.where(mask, pred_metric, np.nan), cmap="viridis", vmin=vmin, vmax=vmax)
    plt.title("Predicted (Metric)"); plt.colorbar(fraction=0.046, pad=0.04); plt.axis("off")
    plt.subplot(1, 4, 4); plt.imshow(np.where(mask, pred_aligned, np.nan), cmap="viridis", vmin=vmin, vmax=vmax)
    plt.title("Predicted (Aligned)"); plt.colorbar(fraction=0.046, pad=0.04); plt.axis("off")
    plt.tight_layout(); plt.savefig(save_path, dpi=150); plt.close()

# ================== 指标函数 ==================
def compute_abs_rel(pred, gt, mask):
    valid = mask & (gt > 0) & np.isfinite(gt) & np.isfinite(pred)
    pred, gt = pred[valid], gt[valid]
    return np.mean(np.abs(pred - gt) / gt) if gt.size else np.nan

def compute_delta1(pred, gt, mask):
    valid = mask & (gt > 1e-6) & (pred > 1e-6) & np.isfinite(gt) & np.isfinite(pred)
    pred, gt = pred[valid], gt[valid]
    if gt.size == 0:
        return np.nan
    thresh = np.maximum(pred / gt, gt / pred)
    return np.mean(thresh < 1.25)

def scale_match(pred, gt, mask):
    valid = mask & np.isfinite(gt) & np.isfinite(pred)
    pv, gv = pred[valid], gt[valid]
    denom = np.sum(pv ** 2)
    return float(np.sum(gv * pv) / denom) if denom > 0 else 1.0

# ================== 单个 scan 处理 ==================
def process_scan(scan_path, split, scene, scan, output_root, global_rows):
    vis_dir = os.path.join(output_root, "visualizations", split, scene, scan)
    csv_path = os.path.join(output_root, "csv", split, scene)
    os.makedirs(csv_path, exist_ok=True)
    csv_file = os.path.join(csv_path, f"{scan}.csv")

    rows = []

    for img_file in sorted(os.listdir(scan_path)):
        if not img_file.endswith(".png"):
            continue
        try:
            rgb_path = os.path.join(scan_path, img_file)
            gt_path = rgb_path.replace(".png", "_depth.npy")
            mask_path = rgb_path.replace(".png", "_depth_mask.npy")
            if not (os.path.exists(gt_path) and os.path.exists(mask_path)):
                print(f"[缺GT/Mask] 跳过: {split}/{scene}/{scan}/{img_file}")
                continue

            # 读取
            rgb = cv2.cvtColor(cv2.imread(rgb_path), cv2.COLOR_BGR2RGB)
            gt = np.load(gt_path).astype(np.float32)
            if gt.ndim == 3: gt = gt[:, :, 0]
            mask = np.load(mask_path).astype(bool)

            # 推理
            input_image = Image.fromarray(rgb)
            inputs = processor(images=input_image, return_tensors="pt").to(device)
            with torch.no_grad():
                outputs = model(**inputs)
            processed = processor.post_process_depth_estimation(
                outputs, source_sizes=[(rgb.shape[0], rgb.shape[1])]
            )
            pred_metric = processed[0]["predicted_depth"].squeeze().cpu().numpy()

            # 尺寸对齐
            if pred_metric.shape != gt.shape:
                pred_metric = cv2.resize(pred_metric, (gt.shape[1], gt.shape[0]), interpolation=cv2.INTER_LINEAR)

            # Metric（原始预测）
            absrel_metric = compute_abs_rel(pred_metric, gt, mask)
            delta1_metric = compute_delta1(pred_metric, gt, mask)

            # Relative（scale 对齐）
            s = scale_match(pred_metric, gt, mask)
            pred_aligned = pred_metric * s
            absrel_rel = compute_abs_rel(pred_aligned, gt, mask)
            delta1_rel = compute_delta1(pred_aligned, gt, mask)

            print(f"[{split}/{scene}/{scan}/{img_file}] "
                  f"Metric: AbsRel {absrel_metric:.4f}, δ1 {delta1_metric*100:.2f}% | "
                  f"Relative: AbsRel {absrel_rel:.4f}, δ1 {delta1_rel*100:.2f}%")

            # 记录
            row = [split, scene, scan, img_file,
                   absrel_metric, delta1_metric, absrel_rel, delta1_rel]
            rows.append(row)
            global_rows.append(row)

            # 可视化
            save_comparison_figure(img_file, rgb, gt, pred_metric, pred_aligned, mask, vis_dir)

            # 释放
            del rgb, gt, mask, pred_metric, pred_aligned, inputs, outputs, processed, input_image
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

        except Exception as e:
            print(f"[失败] {split}/{scene}/{scan}/{img_file}: {e}")
            continue

    # 保存 per-scan CSV（含均值行）
    if rows:
        df = pd.DataFrame(rows, columns=[
            "split","scene","scan","image",
            "AbsRel_metric","Delta1_metric","AbsRel_relative","Delta1_relative"
        ])
        mean_row = pd.DataFrame([[
            df["split"].iloc[0], df["scene"].iloc[0], df["scan"].iloc[0], "mean",
            df["AbsRel_metric"].mean(),
            df["Delta1_metric"].mean(),
            df["AbsRel_relative"].mean(),
            df["Delta1_relative"].mean()
        ]], columns=df.columns)
        df = pd.concat([df, mean_row], ignore_index=True)
        df.to_csv(csv_file, index=False)
        print(f"[保存] CSV: {csv_file}")

        # 打包可视化
        zip_path = os.path.join(output_root, f"visualizations_{split}_{scene}_{scan}.zip")
        shutil.make_archive(base_name=zip_path.replace(".zip",""), format="zip", root_dir=vis_dir)
        print(f"[打包] {zip_path}")

# ================== 主流程：一次性测试所有 scan ==================
val_root = "/kaggle/input/diode-val/val"
output_root = "/kaggle/working"
os.makedirs(os.path.join(output_root, "csv"), exist_ok=True)

global_rows = []
splits = ["indoors", "outdoor"]
for split in splits:
    split_root = os.path.join(val_root, split)
    if not os.path.isdir(split_root):
        continue
    for scene in sorted(os.listdir(split_root)):
        scene_path = os.path.join(split_root, scene)
        if not os.path.isdir(scene_path):
            continue
        for scan in sorted(os.listdir(scene_path)):
            scan_path = os.path.join(scene_path, scan)
            if not os.path.isdir(scan_path):
                continue
            print(f"\n=== 处理 {split}/{scene}/{scan} ===")
            process_scan(scan_path, split, scene, scan, output_root, global_rows)

# ================== 全量汇总 CSV ==================
if global_rows:
    all_df = pd.DataFrame(global_rows, columns=[
        "split","scene","scan","image",
        "AbsRel_metric","Delta1_metric","AbsRel_relative","Delta1_relative"
    ])
    # 可再加整体均值一行
    overall_mean = pd.DataFrame([[
        "ALL","ALL","ALL","mean",
        all_df["AbsRel_metric"].mean(),
        all_df["Delta1_metric"].mean(),
        all_df["AbsRel_relative"].mean(),
        all_df["Delta1_relative"].mean()
    ]], columns=all_df.columns)
    all_df = pd.concat([all_df, overall_mean], ignore_index=True)

    all_csv = os.path.join(output_root, "eval_results_all_scans.csv")
    all_df.to_csv(all_csv, index=False)
    print(f"\n[汇总] 全量结果保存至: {all_csv}")

gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# 2025-08-12 16:51:34.569907: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755017494.763463      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755017494.821073      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# preprocessor_config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.38G [00:00<?, ?B/s]
# === 处理 indoors/scene_00019/scan_00183 ===
# [indoors/scene_00019/scan_00183/00019_00183_indoors_000_010.png] Metric: AbsRel 0.5210, δ1 0.95% | Relative: AbsRel 0.0746, δ1 94.33%
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# [indoors/scene_00019/scan_00183/00019_00183_indoors_000_040.png] Metric: AbsRel 0.7531, δ1 0.00% | Relative: AbsRel 0.1095, δ1 91.68%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_010_000.png] Metric: AbsRel 0.4156, δ1 3.09% | Relative: AbsRel 0.0895, δ1 92.93%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_010_020.png] Metric: AbsRel 0.6568, δ1 0.01% | Relative: AbsRel 0.0610, δ1 97.79%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_020_030.png] Metric: AbsRel 0.7137, δ1 0.01% | Relative: AbsRel 0.0395, δ1 99.07%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_020_050.png] Metric: AbsRel 0.7144, δ1 0.02% | Relative: AbsRel 0.1143, δ1 96.85%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_030_010.png] Metric: AbsRel 0.4941, δ1 1.06% | Relative: AbsRel 0.0657, δ1 93.30%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_030_040.png] Metric: AbsRel 0.6890, δ1 0.01% | Relative: AbsRel 0.0816, δ1 92.00%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_040_000.png] Metric: AbsRel 0.3924, δ1 4.65% | Relative: AbsRel 0.0763, δ1 91.41%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_040_030.png] Metric: AbsRel 0.6998, δ1 0.01% | Relative: AbsRel 0.0332, δ1 99.56%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_050_010.png] Metric: AbsRel 0.4910, δ1 0.48% | Relative: AbsRel 0.0468, δ1 98.78%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_060_000.png] Metric: AbsRel 0.3243, δ1 5.99% | Relative: AbsRel 0.0632, δ1 94.08%
# [indoors/scene_00019/scan_00183/00019_00183_indoors_080_000.png] Metric: AbsRel 0.3647, δ1 4.25% | Relative: AbsRel 0.0773, δ1 91.18%
# [indoors/scene_00019/scan_00183/00019_00183_indoors

# [indoors/scene_00020/scan_00187/00020_00187_indoors_260_010.png] Metric: AbsRel 0.2102, δ1 71.13% | Relative: AbsRel 0.0887, δ1 90.73%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_260_030.png] Metric: AbsRel 0.0536, δ1 95.59% | Relative: AbsRel 0.0645, δ1 95.56%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_270_000.png] Metric: AbsRel 0.2121, δ1 60.34% | Relative: AbsRel 0.1013, δ1 89.05%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_270_020.png] Metric: AbsRel 0.1455, δ1 84.88% | Relative: AbsRel 0.0842, δ1 91.31%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_280_010.png] Metric: AbsRel 0.2222, δ1 38.11% | Relative: AbsRel 0.0794, δ1 89.98%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_280_030.png] Metric: AbsRel 0.0798, δ1 99.21% | Relative: AbsRel 0.0494, δ1 99.28%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_290_000.png] Metric: AbsRel 0.1756, δ1 84.26% | Relative: AbsRel 0.0584, δ1 96.54%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_290_020.png] Metric: AbsRel 0.1501, δ1 98.20% | Relative: AbsRel 0.0183, δ1 99.71%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_300_010.png] Metric: AbsRel 0.1575, δ1 69.82% | Relative: AbsRel 0.0967, δ1 92.42%
# [indoors/scene_00020/scan_00187/00020_00187_indoors_310_000.png] Metric: AbsRel 0.1892, δ1 41.21% | Relative: AbsRel 0.0891, δ1 97.45%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00020/scan_00187.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00020_scan_00187.zip
#
# === 处理 indoors/scene_00021/scan_00188 ===
# [indoors/scene_00021/scan_00188/00021_00188_indoors_090_000.png] Metric: AbsRel 0.1533, δ1 66.75% | Relative: AbsRel 0.5023, δ1 9.02%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_090_020.png] Metric: AbsRel 0.1657, δ1 87.62% | Relative: AbsRel 0.9368, δ1 3.78%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_100_010.png] Metric: AbsRel 0.2811, δ1 46.60% | Relative: AbsRel 0.6618, δ1 29.27%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_100_030.png] Metric: AbsRel 0.1936, δ1 79.08% | Relative: AbsRel 0.5386, δ1 8.82%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_110_000.png] Metric: AbsRel 0.3501, δ1 7.98% | Relative: AbsRel 0.2513, δ1 56.67%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_110_020.png] Metric: AbsRel 0.2076, δ1 64.87% | Relative: AbsRel 0.6844, δ1 26.45%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_110_040.png] Metric: AbsRel 0.0626, δ1 98.32% | Relative: AbsRel 0.0618, δ1 98.33%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_120_010.png] Metric: AbsRel 0.3485, δ1 22.52% | Relative: AbsRel 0.4434, δ1 42.29%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_120_030.png] Metric: AbsRel 0.1765, δ1 79.84% | Relative: AbsRel 0.5251, δ1 10.68%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_130_000.png] Metric: AbsRel 0.3396, δ1 1.18% | Relative: AbsRel 0.1419, δ1 86.87%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_130_020.png] Metric: AbsRel 0.1460, δ1 72.45% | Relative: AbsRel 0.4417, δ1 12.47%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_150_000.png] Metric: AbsRel 0.2879, δ1 15.38% | Relative: AbsRel 0.0686, δ1 98.95%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_170_000.png] Metric: AbsRel 0.3362, δ1 2.41% | Relative: AbsRel 0.0586, δ1 97.52%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_170_020.png] Metric: AbsRel 0.2421, δ1 17.68% | Relative: AbsRel 0.0480, δ1 99.64%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_180_010.png] Metric: AbsRel 0.3671, δ1 1.21% | Relative: AbsRel 0.0501, δ1 97.35%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_180_040.png] Metric: AbsRel 0.0814, δ1 99.03% | Relative: AbsRel 0.0700, δ1 98.83%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_190_030.png] Metric: AbsRel 0.1765, δ1 72.42% | Relative: AbsRel 0.0511, δ1 96.82%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_200_020.png] Metric: AbsRel 0.2908, δ1 2.32% | Relative: AbsRel 0.0305, δ1 97.96%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_200_040.png] Metric: AbsRel 0.1153, δ1 95.76% | Relative: AbsRel 0.0636, δ1 97.45%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_210_030.png] Metric: AbsRel 0.2429, δ1 32.27% | Relative: AbsRel 0.1073, δ1 94.30%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_210_050.png] Metric: AbsRel 0.1256, δ1 94.31% | Relative: AbsRel 0.0564, δ1 96.38%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_220_040.png] Metric: AbsRel 0.1140, δ1 97.03% | Relative: AbsRel 0.0594, δ1 95.40%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_230_020.png] Metric: AbsRel 0.2464, δ1 5.35% | Relative: AbsRel 0.0315, δ1 98.89%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_240_040.png] Metric: AbsRel 0.0863, δ1 97.09% | Relative: AbsRel 0.0940, δ1 97.22%
# [indoors/scene_00021/scan_00188/00021_00188_indoors_250_000.png] Metric: AbsRel 0.3862, δ1 4.45% | Relative: AbsRel 0.1224, δ1 93.39%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00021/scan_00188.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00021_scan_00188.zip
#
# === 处理 indoors/scene_00021/scan_00189 ===
# [indoors/scene_00021/scan_00189/00021_00189_indoors_000_000.png] Metric: AbsRel 0.4363, δ1 6.01% | Relative: AbsRel 0.3546, δ1 41.81%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_000_020.png] Metric: AbsRel 0.2577, δ1 55.52% | Relative: AbsRel 0.5074, δ1 22.30%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_000_040.png] Metric: AbsRel 0.2804, δ1 47.85% | Relative: AbsRel 0.1117, δ1 94.59%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_010_010.png] Metric: AbsRel 0.3082, δ1 12.12% | Relative: AbsRel 0.3881, δ1 26.95%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_010_030.png] Metric: AbsRel 0.1685, δ1 90.80% | Relative: AbsRel 0.2272, δ1 90.69%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_130_000.png] Metric: AbsRel 0.3821, δ1 0.90% | Relative: AbsRel 0.0508, δ1 98.41%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_150_030.png] Metric: AbsRel 0.1566, δ1 91.06% | Relative: AbsRel 0.0619, δ1 93.91%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_160_020.png] Metric: AbsRel 0.2595, δ1 27.42% | Relative: AbsRel 0.0941, δ1 99.08%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_190_020.png] Metric: AbsRel 0.1833, δ1 69.20% | Relative: AbsRel 0.0474, δ1 99.15%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_200_010.png] Metric: AbsRel 0.1766, δ1 95.09% | Relative: AbsRel 0.0978, δ1 95.71%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_210_000.png] Metric: AbsRel 0.2517, δ1 36.05% | Relative: AbsRel 0.1037, δ1 96.89%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_210_020.png] Metric: AbsRel 0.1629, δ1 86.98% | Relative: AbsRel 0.0389, δ1 98.05%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_220_010.png] Metric: AbsRel 0.1659, δ1 91.54% | Relative: AbsRel 0.0500, δ1 97.58%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_220_030.png] Metric: AbsRel 0.0877, δ1 97.90% | Relative: AbsRel 0.0447, δ1 98.13%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_230_000.png] Metric: AbsRel 0.2262, δ1 18.47% | Relative: AbsRel 0.0435, δ1 98.11%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_230_020.png] Metric: AbsRel 0.1514, δ1 80.09% | Relative: AbsRel 0.0695, δ1 98.53%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_240_030.png] Metric: AbsRel 0.1738, δ1 70.11% | Relative: AbsRel 0.1531, δ1 79.86%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_330_010.png] Metric: AbsRel 0.2718, δ1 64.72% | Relative: AbsRel 0.7194, δ1 19.89%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_340_000.png] Metric: AbsRel 0.3205, δ1 47.84% | Relative: AbsRel 0.7687, δ1 36.78%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_340_020.png] Metric: AbsRel 0.4182, δ1 8.59% | Relative: AbsRel 0.9836, δ1 15.27%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_350_010.png] Metric: AbsRel 0.3418, δ1 23.18% | Relative: AbsRel 0.4624, δ1 37.45%
# [indoors/scene_00021/scan_00189/00021_00189_indoors_350_030.png] Metric: AbsRel 0.3196, δ1 50.22% | Relative: AbsRel 0.6541, δ1 2.92%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00021/scan_00189.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00021_scan_00189.zip
#
# === 处理 indoors/scene_00021/scan_00190 ===
# [indoors/scene_00021/scan_00190/00021_00190_indoors_050_000.png] Metric: AbsRel 0.1184, δ1 94.79% | Relative: AbsRel 0.1168, δ1 94.85%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_050_030.png] Metric: AbsRel 0.1651, δ1 97.53% | Relative: AbsRel 0.0435, δ1 96.53%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_060_010.png] Metric: AbsRel 0.1316, δ1 94.97% | Relative: AbsRel 0.0980, δ1 93.41%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_060_040.png] Metric: AbsRel 0.2960, δ1 28.13% | Relative: AbsRel 0.0672, δ1 98.47%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_070_000.png] Metric: AbsRel 0.1554, δ1 86.50% | Relative: AbsRel 0.1642, δ1 87.54%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_070_030.png] Metric: AbsRel 0.2563, δ1 49.61% | Relative: AbsRel 0.1156, δ1 86.16%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_080_010.png] Metric: AbsRel 0.1349, δ1 92.45% | Relative: AbsRel 0.1138, δ1 91.35%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_090_000.png] Metric: AbsRel 0.2310, δ1 44.21% | Relative: AbsRel 0.2168, δ1 87.91%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_090_030.png] Metric: AbsRel 0.1155, δ1 92.84% | Relative: AbsRel 0.0913, δ1 91.07%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_100_010.png] Metric: AbsRel 0.1607, δ1 84.85% | Relative: AbsRel 0.1137, δ1 93.18%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_110_000.png] Metric: AbsRel 0.2479, δ1 71.89% | Relative: AbsRel 0.1901, δ1 80.10%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_110_050.png] Metric: AbsRel 0.1397, δ1 82.79% | Relative: AbsRel 0.1022, δ1 95.80%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_120_020.png] Metric: AbsRel 0.1481, δ1 99.12% | Relative: AbsRel 0.0570, δ1 98.67%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_130_030.png] Metric: AbsRel 0.0877, δ1 99.10% | Relative: AbsRel 0.0412, δ1 97.21%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_140_020.png] Metric: AbsRel 0.1326, δ1 70.11% | Relative: AbsRel 0.1215, δ1 96.34%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_140_040.png] Metric: AbsRel 0.0779, δ1 96.10% | Relative: AbsRel 0.0694, δ1 93.77%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_150_030.png] Metric: AbsRel 0.1222, δ1 96.23% | Relative: AbsRel 0.0570, δ1 96.40%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_150_050.png] Metric: AbsRel 0.1002, δ1 96.13% | Relative: AbsRel 0.1022, δ1 96.63%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_190_000.png] Metric: AbsRel 0.3758, δ1 2.80% | Relative: AbsRel 0.0799, δ1 95.05%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_270_010.png] Metric: AbsRel 0.1784, δ1 83.53% | Relative: AbsRel 0.2787, δ1 27.29%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_280_000.png] Metric: AbsRel 0.3351, δ1 20.89% | Relative: AbsRel 0.2925, δ1 72.58%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_280_020.png] Metric: AbsRel 0.0936, δ1 87.06% | Relative: AbsRel 0.3524, δ1 7.15%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_290_010.png] Metric: AbsRel 0.1619, δ1 81.86% | Relative: AbsRel 0.4880, δ1 12.93%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_300_000.png] Metric: AbsRel 0.1945, δ1 66.12% | Relative: AbsRel 0.5899, δ1 22.63%
# [indoors/scene_00021/scan_00190/00021_00190_indoors_300_020.png] Metric: AbsRel 0.2350, δ1 53.75% | Relative: AbsRel 0.6081, δ1 6.87%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00021/scan_00190.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00021_scan_00190.zip
#
# === 处理 indoors/scene_00021/scan_00191 ===
# [indoors/scene_00021/scan_00191/00021_00191_indoors_000_040.png] Metric: AbsRel 0.0974, δ1 99.94% | Relative: AbsRel 0.0576, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_010_030.png] Metric: AbsRel 0.0942, δ1 97.73% | Relative: AbsRel 0.0385, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_020_040.png] Metric: AbsRel 0.0494, δ1 100.00% | Relative: AbsRel 0.0404, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_060_050.png] Metric: AbsRel 0.0720, δ1 97.04% | Relative: AbsRel 0.0699, δ1 99.60%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_080_050.png] Metric: AbsRel 0.2466, δ1 47.64% | Relative: AbsRel 0.0372, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_220_000.png] Metric: AbsRel 0.2185, δ1 36.25% | Relative: AbsRel 0.1494, δ1 77.40%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_220_020.png] Metric: AbsRel 0.0671, δ1 100.00% | Relative: AbsRel 0.0661, δ1 99.98%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_220_040.png] Metric: AbsRel 0.2184, δ1 75.52% | Relative: AbsRel 0.0661, δ1 98.49%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_230_010.png] Metric: AbsRel 0.2025, δ1 33.14% | Relative: AbsRel 0.1100, δ1 85.10%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_230_030.png] Metric: AbsRel 0.0939, δ1 99.81% | Relative: AbsRel 0.0503, δ1 99.90%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_230_050.png] Metric: AbsRel 0.0830, δ1 99.99% | Relative: AbsRel 0.0455, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_260_030.png] Metric: AbsRel 0.1687, δ1 80.10% | Relative: AbsRel 0.3354, δ1 21.44%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_280_030.png] Metric: AbsRel 0.1528, δ1 79.66% | Relative: AbsRel 0.1732, δ1 78.16%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_330_030.png] Metric: AbsRel 0.3188, δ1 0.00% | Relative: AbsRel 0.0367, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_340_000.png] Metric: AbsRel 0.3719, δ1 0.53% | Relative: AbsRel 0.0702, δ1 97.42%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_340_020.png] Metric: AbsRel 0.3551, δ1 0.00% | Relative: AbsRel 0.0238, δ1 99.93%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_340_040.png] Metric: AbsRel 0.2584, δ1 4.16% | Relative: AbsRel 0.0367, δ1 100.00%
# [indoors/scene_00021/scan_00191/00021_00191_indoors_350_030.png] Metric: AbsRel 0.2184, δ1 31.99% | Relative: AbsRel 0.0453, δ1 100.00%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00021/scan_00191.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00021_scan_00191.zip
#
# === 处理 indoors/scene_00021/scan_00192 ===
# [indoors/scene_00021/scan_00192/00021_00192_indoors_000_000.png] Metric: AbsRel 0.2732, δ1 3.68% | Relative: AbsRel 0.0384, δ1 94.40%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_000_020.png] Metric: AbsRel 0.1107, δ1 98.82% | Relative: AbsRel 0.0340, δ1 99.27%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_010_010.png] Metric: AbsRel 0.1632, δ1 87.15% | Relative: AbsRel 0.0448, δ1 98.38%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_010_030.png] Metric: AbsRel 0.1797, δ1 81.15% | Relative: AbsRel 0.0780, δ1 99.48%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_020_000.png] Metric: AbsRel 0.3312, δ1 1.42% | Relative: AbsRel 0.0529, δ1 98.52%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_020_020.png] Metric: AbsRel 0.0656, δ1 99.55% | Relative: AbsRel 0.0481, δ1 99.71%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_030_010.png] Metric: AbsRel 0.2890, δ1 0.74% | Relative: AbsRel 0.0344, δ1 98.20%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_030_030.png] Metric: AbsRel 0.1954, δ1 77.57% | Relative: AbsRel 0.0811, δ1 98.47%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_040_000.png] Metric: AbsRel 0.3220, δ1 1.99% | Relative: AbsRel 0.0527, δ1 98.07%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_220_000.png] Metric: AbsRel 0.1365, δ1 82.90% | Relative: AbsRel 0.0945, δ1 93.58%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_230_010.png] Metric: AbsRel 0.1402, δ1 83.08% | Relative: AbsRel 0.2817, δ1 35.06%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_240_000.png] Metric: AbsRel 0.2046, δ1 58.50% | Relative: AbsRel 0.2947, δ1 41.62%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_240_020.png] Metric: AbsRel 0.2023, δ1 72.50% | Relative: AbsRel 0.3379, δ1 42.17%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_300_000.png] Metric: AbsRel 0.4735, δ1 0.22% | Relative: AbsRel 0.4177, δ1 11.37%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_300_020.png] Metric: AbsRel 0.2209, δ1 59.65% | Relative: AbsRel 0.5471, δ1 27.25%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_310_010.png] Metric: AbsRel 0.3795, δ1 7.40% | Relative: AbsRel 0.4367, δ1 27.56%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_310_030.png] Metric: AbsRel 0.1474, δ1 86.56% | Relative: AbsRel 0.5195, δ1 5.18%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_320_000.png] Metric: AbsRel 0.3945, δ1 0.52% | Relative: AbsRel 0.5142, δ1 8.71%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_320_020.png] Metric: AbsRel 0.1577, δ1 82.84% | Relative: AbsRel 0.5759, δ1 11.67%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_330_010.png] Metric: AbsRel 0.1298, δ1 96.48% | Relative: AbsRel 0.0787, δ1 95.83%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_330_030.png] Metric: AbsRel 0.1643, δ1 95.91% | Relative: AbsRel 0.0489, δ1 97.97%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_340_000.png] Metric: AbsRel 0.3127, δ1 2.05% | Relative: AbsRel 0.0363, δ1 98.77%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_340_020.png] Metric: AbsRel 0.0933, δ1 98.56% | Relative: AbsRel 0.0367, δ1 99.07%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_350_010.png] Metric: AbsRel 0.1286, δ1 93.50% | Relative: AbsRel 0.0516, δ1 98.91%
# [indoors/scene_00021/scan_00192/00021_00192_indoors_350_030.png] Metric: AbsRel 0.0616, δ1 99.36% | Relative: AbsRel 0.0406, δ1 99.49%
# [保存] CSV: /kaggle/working/csv/indoors/scene_00021/scan_00192.csv
# [打包] /kaggle/working/visualizations_indoors_scene_00021_scan_00192.zip
#
# === 处理 outdoor/scene_00022/scan_00193 ===
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_000.png] Metric: AbsRel 0.6319, δ1 2.06% | Relative: AbsRel 0.5776, δ1 15.23%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_020.png] Metric: AbsRel 0.5343, δ1 11.85% | Relative: AbsRel 0.5560, δ1 73.24%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_000_040.png] Metric: AbsRel 0.5992, δ1 1.34% | Relative: AbsRel 0.1641, δ1 91.62%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_010_010.png] Metric: AbsRel 0.3280, δ1 71.90% | Relative: AbsRel 0.3627, δ1 69.79%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_010_030.png] Metric: AbsRel 0.5139, δ1 2.75% | Relative: AbsRel 0.1710, δ1 89.43%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_020_000.png] Metric: AbsRel 0.6021, δ1 1.66% | Relative: AbsRel 0.6966, δ1 6.09%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_030_020.png] Metric: AbsRel 0.4379, δ1 30.11% | Relative: AbsRel 0.4859, δ1 60.44%
# [outdoor/scene_00022/scan_00193/00022_00193_outdoor_030_040.png] Metric: AbsRel 0.5167, δ1 3.23% | Relative: AbsRel 0.2385, δ1 63.45%
# ...
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_020_030.png] Metric: AbsRel 0.1474, δ1 91.25% | Relative: AbsRel 0.1324, δ1 91.23%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_020_050.png] Metric: AbsRel 0.2193, δ1 70.59% | Relative: AbsRel 0.2066, δ1 76.60%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_030_000.png] Metric: AbsRel 0.5216, δ1 0.73% | Relative: AbsRel 0.0757, δ1 96.46%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_030_020.png] Metric: AbsRel 0.0913, δ1 95.42% | Relative: AbsRel 0.0934, δ1 95.51%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_030_040.png] Metric: AbsRel 0.1597, δ1 85.44% | Relative: AbsRel 0.1383, δ1 90.72%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_040_010.png] Metric: AbsRel 0.5835, δ1 16.42% | Relative: AbsRel 0.3082, δ1 70.85%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_040_030.png] Metric: AbsRel 0.1068, δ1 90.57% | Relative: AbsRel 0.1942, δ1 90.19%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_050_000.png] Metric: AbsRel 0.5869, δ1 0.84% | Relative: AbsRel 1.1532, δ1 1.79%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_050_020.png] Metric: AbsRel 0.2704, δ1 80.72% | Relative: AbsRel 0.9093, δ1 2.46%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_070_010.png] Metric: AbsRel 0.8891, δ1 15.33% | Relative: AbsRel 1.1087, δ1 3.58%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_080_000.png] Metric: AbsRel 0.6494, δ1 0.91% | Relative: AbsRel 1.0442, δ1 3.46%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_080_020.png] Metric: AbsRel 1.2262, δ1 42.85% | Relative: AbsRel 1.9333, δ1 15.62%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_090_010.png] Metric: AbsRel 1.1144, δ1 31.31% | Relative: AbsRel 0.6594, δ1 72.27%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_100_000.png] Metric: AbsRel 0.6449, δ1 0.99% | Relative: AbsRel 0.2782, δ1 72.32%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_100_020.png] Metric: AbsRel 1.1475, δ1 52.88% | Relative: AbsRel 0.8349, δ1 20.53%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_120_010.png] Metric: AbsRel 1.0742, δ1 32.47% | Relative: AbsRel 0.6036, δ1 17.56%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_130_000.png] Metric: AbsRel 0.6479, δ1 0.98% | Relative: AbsRel 0.2620, δ1 80.28%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_130_020.png] Metric: AbsRel 1.2140, δ1 51.15% | Relative: AbsRel 0.8533, δ1 21.51%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_190_030.png] Metric: AbsRel 0.9417, δ1 47.70% | Relative: AbsRel 1.8520, δ1 6.02%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_210_030.png] Metric: AbsRel 0.8973, δ1 34.83% | Relative: AbsRel 2.2138, δ1 5.98%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_280_030.png] Metric: AbsRel 0.2094, δ1 87.97% | Relative: AbsRel 0.2105, δ1 85.45%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_290_000.png] Metric: AbsRel 0.5516, δ1 8.87% | Relative: AbsRel 0.5335, δ1 61.05%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_290_020.png] Metric: AbsRel 0.4775, δ1 72.71% | Relative: AbsRel 0.4468, δ1 72.16%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_300_010.png] Metric: AbsRel 0.6339, δ1 49.03% | Relative: AbsRel 0.3813, δ1 70.60%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_300_040.png] Metric: AbsRel 0.2502, δ1 43.65% | Relative: AbsRel 0.2148, δ1 65.52%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_310_000.png] Metric: AbsRel 0.6410, δ1 2.40% | Relative: AbsRel 0.5430, δ1 25.70%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_310_020.png] Metric: AbsRel 0.5062, δ1 22.79% | Relative: AbsRel 0.4962, δ1 50.48%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_320_010.png] Metric: AbsRel 0.4306, δ1 63.16% | Relative: AbsRel 0.3209, δ1 74.84%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_330_000.png] Metric: AbsRel 0.6689, δ1 0.23% | Relative: AbsRel 0.3802, δ1 32.20%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_330_030.png] Metric: AbsRel 0.5808, δ1 6.62% | Relative: AbsRel 0.5073, δ1 32.21%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_340_010.png] Metric: AbsRel 0.4695, δ1 62.77% | Relative: AbsRel 0.2877, δ1 81.57%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_340_040.png] Metric: AbsRel 0.4248, δ1 17.31% | Relative: AbsRel 0.3510, δ1 67.87%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_350_000.png] Metric: AbsRel 0.6272, δ1 0.30% | Relative: AbsRel 0.1561, δ1 86.84%
# [outdoor/scene_00023/scan_00200/00023_00200_outdoor_350_030.png] Metric: AbsRel 0.3335, δ1 24.80% | Relative: AbsRel 0.2967, δ1 48.57%
# [保存] CSV: /kaggle/working/csv/outdoor/scene_00023/scan_00200.csv
# [打包] /kaggle/working/visualizations_outdoor_scene_00023_scan_00200.zip
#
# === 处理 outdoor/scene_00024/scan_00201 ===
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_000_000.png] Metric: AbsRel 0.5921, δ1 3.56% | Relative: AbsRel 1.0389, δ1 7.31%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_000_020.png] Metric: AbsRel 1.0651, δ1 19.94% | Relative: AbsRel 1.6384, δ1 17.06%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_010_010.png] Metric: AbsRel 1.7829, δ1 10.65% | Relative: AbsRel 1.5049, δ1 17.23%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_030_000.png] Metric: AbsRel 0.5766, δ1 4.12% | Relative: AbsRel 0.9522, δ1 10.86%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_050_030.png] Metric: AbsRel 0.9561, δ1 12.01% | Relative: AbsRel 1.4156, δ1 38.23%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_060_000.png] Metric: AbsRel 0.5845, δ1 3.11% | Relative: AbsRel 0.8785, δ1 11.53%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_060_040.png] Metric: AbsRel 0.7274, δ1 13.80% | Relative: AbsRel 0.9089, δ1 29.97%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_070_010.png] Metric: AbsRel 0.9497, δ1 30.17% | Relative: AbsRel 0.7860, δ1 33.19%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_070_030.png] Metric: AbsRel 0.6642, δ1 7.49% | Relative: AbsRel 0.6830, δ1 71.38%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_080_000.png] Metric: AbsRel 0.5292, δ1 4.90% | Relative: AbsRel 0.3927, δ1 54.03%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_080_020.png] Metric: AbsRel 0.3857, δ1 12.26% | Relative: AbsRel 0.2592, δ1 81.31%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_080_040.png] Metric: AbsRel 0.4635, δ1 3.83% | Relative: AbsRel 0.2238, δ1 89.11%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_090_010.png] Metric: AbsRel 0.7487, δ1 41.70% | Relative: AbsRel 0.4405, δ1 61.58%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_090_030.png] Metric: AbsRel 0.4074, δ1 5.04% | Relative: AbsRel 0.1959, δ1 90.09%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_090_050.png] Metric: AbsRel 0.5166, δ1 0.57% | Relative: AbsRel 0.0854, δ1 95.88%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_100_000.png] Metric: AbsRel 0.5391, δ1 4.09% | Relative: AbsRel 0.3357, δ1 55.42%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_100_020.png] Metric: AbsRel 0.3134, δ1 15.47% | Relative: AbsRel 0.1796, δ1 87.75%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_100_040.png] Metric: AbsRel 0.4461, δ1 1.39% | Relative: AbsRel 0.0914, δ1 95.77%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_110_010.png] Metric: AbsRel 0.6785, δ1 0.83% | Relative: AbsRel 0.2927, δ1 72.12%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_110_030.png] Metric: AbsRel 0.4171, δ1 2.11% | Relative: AbsRel 0.0798, δ1 94.69%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_110_050.png] Metric: AbsRel 0.5274, δ1 0.49% | Relative: AbsRel 0.0837, δ1 96.18%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_120_000.png] Metric: AbsRel 0.5749, δ1 2.09% | Relative: AbsRel 0.3196, δ1 63.99%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_120_020.png] Metric: AbsRel 0.8027, δ1 0.15% | Relative: AbsRel 0.1535, δ1 85.02%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_130_010.png] Metric: AbsRel 0.6870, δ1 0.48% | Relative: AbsRel 0.2150, δ1 77.83%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_130_040.png] Metric: AbsRel 0.5544, δ1 0.44% | Relative: AbsRel 0.0920, δ1 97.39%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_140_020.png] Metric: AbsRel 0.2444, δ1 40.06% | Relative: AbsRel 0.1470, δ1 89.83%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_140_050.png] Metric: AbsRel 0.6010, δ1 0.31% | Relative: AbsRel 0.1182, δ1 96.07%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_150_030.png] Metric: AbsRel 0.4800, δ1 6.92% | Relative: AbsRel 0.2335, δ1 85.09%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_160_040.png] Metric: AbsRel 0.5923, δ1 10.53% | Relative: AbsRel 0.5986, δ1 53.74%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_170_020.png] Metric: AbsRel 0.6164, δ1 33.64% | Relative: AbsRel 0.6273, δ1 39.06%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_170_050.png] Metric: AbsRel 0.6229, δ1 8.85% | Relative: AbsRel 0.6300, δ1 57.09%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_180_030.png] Metric: AbsRel 0.5808, δ1 34.32% | Relative: AbsRel 0.8152, δ1 31.16%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_190_000.png] Metric: AbsRel 0.5915, δ1 3.15% | Relative: AbsRel 0.3795, δ1 69.62%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_190_020.png] Metric: AbsRel 1.1258, δ1 33.43% | Relative: AbsRel 1.0230, δ1 33.54%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_210_020.png] Metric: AbsRel 0.9771, δ1 28.30% | Relative: AbsRel 0.9237, δ1 29.04%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_220_030.png] Metric: AbsRel 0.8986, δ1 15.79% | Relative: AbsRel 1.2219, δ1 20.68%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_230_010.png] Metric: AbsRel 1.0525, δ1 36.17% | Relative: AbsRel 0.6173, δ1 41.21%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_240_000.png] Metric: AbsRel 0.6407, δ1 3.61% | Relative: AbsRel 0.6235, δ1 59.59%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_240_020.png] Metric: AbsRel 1.1962, δ1 18.69% | Relative: AbsRel 1.3104, δ1 20.05%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_320_000.png] Metric: AbsRel 0.6472, δ1 3.32% | Relative: AbsRel 1.4499, δ1 6.08%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_330_010.png] Metric: AbsRel 1.2565, δ1 17.13% | Relative: AbsRel 1.4961, δ1 11.67%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_340_000.png] Metric: AbsRel 0.6228, δ1 2.49% | Relative: AbsRel 1.2501, δ1 6.27%
# [outdoor/scene_00024/scan_00201/00024_00201_outdoor_350_010.png] Metric: AbsRel 1.7973, δ1 10.14% | Relative: AbsRel 1.6322, δ1 13.81%
# [保存] CSV: /kaggle/working/csv/outdoor/scene_00024/scan_00201.csv
# [打包] /kaggle/working/visualizations_outdoor_scene_00024_scan_00201.zip
#
# === 处理 outdoor/scene_00024/scan_00202 ===
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_000_030.png] Metric: AbsRel 0.4239, δ1 21.59% | Relative: AbsRel 0.4189, δ1 36.25%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_070_010.png] Metric: AbsRel 0.6636, δ1 42.13% | Relative: AbsRel 0.5403, δ1 65.65%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_080_030.png] Metric: AbsRel 0.5536, δ1 1.43% | Relative: AbsRel 0.2950, δ1 87.66%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_090_020.png] Metric: AbsRel 0.3301, δ1 75.31% | Relative: AbsRel 0.2915, δ1 88.63%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_100_000.png] Metric: AbsRel 0.5912, δ1 1.77% | Relative: AbsRel 0.3135, δ1 71.56%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_100_030.png] Metric: AbsRel 0.4664, δ1 1.02% | Relative: AbsRel 0.1190, δ1 95.23%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_110_020.png] Metric: AbsRel 0.2550, δ1 75.83% | Relative: AbsRel 0.2451, δ1 75.92%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_110_040.png] Metric: AbsRel 0.5056, δ1 2.13% | Relative: AbsRel 0.1601, δ1 75.14%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_120_000.png] Metric: AbsRel 0.5408, δ1 3.22% | Relative: AbsRel 0.4174, δ1 43.77%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_120_030.png] Metric: AbsRel 0.4491, δ1 8.01% | Relative: AbsRel 0.2345, δ1 39.65%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_130_020.png] Metric: AbsRel 0.3175, δ1 45.34% | Relative: AbsRel 0.3518, δ1 38.85%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_130_040.png] Metric: AbsRel 0.5239, δ1 4.26% | Relative: AbsRel 0.2300, δ1 41.55%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_140_000.png] Metric: AbsRel 0.5070, δ1 2.70% | Relative: AbsRel 0.2722, δ1 72.60%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_140_030.png] Metric: AbsRel 0.3184, δ1 31.93% | Relative: AbsRel 0.2486, δ1 50.82%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_150_020.png] Metric: AbsRel 0.2335, δ1 69.73% | Relative: AbsRel 0.2620, δ1 72.26%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_150_040.png] Metric: AbsRel 0.5505, δ1 11.83% | Relative: AbsRel 0.4084, δ1 55.48%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_160_010.png] Metric: AbsRel 0.5501, δ1 24.57% | Relative: AbsRel 0.2227, δ1 71.58%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_160_030.png] Metric: AbsRel 0.2238, δ1 38.75% | Relative: AbsRel 0.1655, δ1 86.39%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_170_000.png] Metric: AbsRel 0.5125, δ1 2.33% | Relative: AbsRel 0.2198, δ1 80.20%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_170_020.png] Metric: AbsRel 0.2445, δ1 73.95% | Relative: AbsRel 0.2716, δ1 71.46%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_170_040.png] Metric: AbsRel 0.4734, δ1 14.51% | Relative: AbsRel 0.4778, δ1 29.05%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_180_010.png] Metric: AbsRel 0.6297, δ1 1.93% | Relative: AbsRel 0.5057, δ1 22.37%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_180_030.png] Metric: AbsRel 0.3566, δ1 24.35% | Relative: AbsRel 0.4157, δ1 39.49%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_190_000.png] Metric: AbsRel 0.5262, δ1 4.36% | Relative: AbsRel 0.3364, δ1 66.05%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_190_020.png] Metric: AbsRel 0.3325, δ1 45.75% | Relative: AbsRel 0.4089, δ1 53.00%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_200_010.png] Metric: AbsRel 0.6502, δ1 18.87% | Relative: AbsRel 0.4254, δ1 56.03%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_200_040.png] Metric: AbsRel 0.6042, δ1 1.44% | Relative: AbsRel 0.1842, δ1 74.53%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_210_000.png] Metric: AbsRel 0.5621, δ1 3.08% | Relative: AbsRel 0.2828, δ1 73.75%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_210_030.png] Metric: AbsRel 0.4712, δ1 8.51% | Relative: AbsRel 0.3696, δ1 67.36%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_220_020.png] Metric: AbsRel 0.3581, δ1 52.41% | Relative: AbsRel 0.3551, δ1 72.30%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_220_040.png] Metric: AbsRel 0.5067, δ1 7.90% | Relative: AbsRel 0.3917, δ1 59.57%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_230_010.png] Metric: AbsRel 0.6096, δ1 24.80% | Relative: AbsRel 0.4295, δ1 67.65%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_300_030.png] Metric: AbsRel 0.5388, δ1 14.48% | Relative: AbsRel 0.7395, δ1 32.24%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_310_040.png] Metric: AbsRel 0.5794, δ1 8.80% | Relative: AbsRel 0.4486, δ1 50.77%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_320_030.png] Metric: AbsRel 0.4963, δ1 11.21% | Relative: AbsRel 0.3892, δ1 53.19%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_330_040.png] Metric: AbsRel 0.5794, δ1 6.54% | Relative: AbsRel 0.3539, δ1 51.21%
# [outdoor/scene_00024/scan_00202/00024_00202_outdoor_340_030.png] Metric: AbsRel 0.5117, δ1 9.12% | Relative: AbsRel 0.2897, δ1 66.10%
# [保存] CSV: /kaggle/working/csv/outdoor/scene_00024/scan_00202.csv
# [打包] /kaggle/working/visualizations_outdoor_scene_00024_scan_00202.zip
#
# [汇总] 全量结果保存至: /kaggle/working/eval_results_all_scans.csv
